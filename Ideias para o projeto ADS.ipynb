# %% [markdown]
# Ideias para o Projeto para website
#
# * Procurar um diferencial
# * Fazer um palnejamento para a apresentação
# * Escolher um tema e a direção que vamos tomar
# * Montar um grupo
# * Pesquisar no chat GBT (como um web site para um projeto de faculdade de ADS)
#
# Ideias para projetos de virtualisação, magic box
#
# * Conhecer e entender como funciona o magic box
# * ententer como funciona a virtualização e tentar fazer
# * pesquisar sobre processamentos paralelos
#
#
# Ideias para projetos utilizando IA
#
# * Pensar e pesquisar aonde pode ser implantado a IA e como isso seria um diferencial
# * Tentar usar a IA em meios comerciais que nao tem a IA sendo utilizada com frequencia
